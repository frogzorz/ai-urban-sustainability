# %% [markdown]
# # Homework 2 part 1: NAIP Downloader
# ### Cleaned notebook by Jamie Song for MUSA 6950

# %% [markdown]
# This notebook will download the Natural color NAIP images and the false color NAIP images from a database maintained by Microsoft. We need to download NAIP tiles first before doing any raster-based operations, like, mosaci, clip, mask, etc.

# %%
# install packages not in environment
# !pip install pystac_client
# !pip install planetary_computer
# !pip install rioxarray
# Out:
# Requirement already satisfied: pystac_client in /Users/songj/miniforge3/lib/python3.10/site-packages (0.8.5)
# Requirement already satisfied: requests>=2.28.2 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pystac_client) (2.31.0)
# Requirement already satisfied: pystac>=1.10.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pystac[validation]>=1.10.0->pystac_client) (1.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pystac_client) (2.9.0)
# Requirement already satisfied: jsonschema~=4.18 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pystac[validation]>=1.10.0->pystac_client) (4.23.0)
# Requirement already satisfied: six>=1.5 in /Users/songj/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pystac_client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.28.2->pystac_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.28.2->pystac_client) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.28.2->pystac_client) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.28.2->pystac_client) (2024.8.30)
# Requirement already satisfied: attrs>=22.2.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.20.0)
# Requirement already satisfied: planetary_computer in /Users/songj/miniforge3/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: click>=7.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (8.1.7)
# Requirement already satisfied: pydantic>=1.7.3 in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (2.10.6)
# Requirement already satisfied: pystac>=1.0.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (1.12.1)
# Requirement already satisfied: pystac-client>=0.2.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (0.8.5)
# Requirement already satisfied: pytz>=2020.5 in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (2024.1)
# Requirement already satisfied: requests>=2.25.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (2.31.0)
# Requirement already satisfied: packaging in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (24.0)
# Requirement already satisfied: python-dotenv in /Users/songj/miniforge3/lib/python3.10/site-packages (from planetary_computer) (1.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pydantic>=1.7.3->planetary_computer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pydantic>=1.7.3->planetary_computer) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pydantic>=1.7.3->planetary_computer) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pystac>=1.0.0->planetary_computer) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.25.1->planetary_computer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.25.1->planetary_computer) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.25.1->planetary_computer) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/songj/miniforge3/lib/python3.10/site-packages (from requests>=2.25.1->planetary_computer) (2024.8.30)
# Requirement already satisfied: jsonschema~=4.18 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (4.23.0)
# Requirement already satisfied: six>=1.5 in /Users/songj/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7.0->pystac>=1.0.0->planetary_computer) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.2.0->planetary_computer) (0.20.0)
# Requirement already satisfied: rioxarray in /Users/songj/miniforge3/lib/python3.10/site-packages (0.18.2)
# Requirement already satisfied: packaging in /Users/songj/miniforge3/lib/python3.10/site-packages (from rioxarray) (24.0)
# Requirement already satisfied: rasterio>=1.3.7 in /Users/songj/miniforge3/lib/python3.10/site-packages (from rioxarray) (1.4.1)
# Requirement already satisfied: xarray>=2024.7.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from rioxarray) (2025.1.2)
# Requirement already satisfied: pyproj>=3.3 in /Users/songj/miniforge3/lib/python3.10/site-packages (from rioxarray) (3.7.0)
# Requirement already satisfied: numpy>=1.23 in /Users/songj/miniforge3/lib/python3.10/site-packages (from rioxarray) (1.26.4)
# Requirement already satisfied: certifi in /Users/songj/miniforge3/lib/python3.10/site-packages (from pyproj>=3.3->rioxarray) (2024.8.30)
# Requirement already satisfied: affine in /Users/songj/miniforge3/lib/python3.10/site-packages (from rasterio>=1.3.7->rioxarray) (2.4.0)
# Requirement already satisfied: attrs in /Users/songj/miniforge3/lib/python3.10/site-packages (from rasterio>=1.3.7->rioxarray) (24.2.0)
# Requirement already satisfied: click>=4.0 in /Users/songj/miniforge3/lib/python3.10/site-packages (from rasterio>=1.3.7->rioxarray) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /Users/songj/miniforge3/lib/python3.10/site-packages (from rasterio>=1.3.7->rioxarray) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/songj/miniforge3/lib/python3.10/site-packages (from rasterio>=1.3.7->rioxarray) (1.1.1)
# Requirement already satisfied: pyparsing in /Users/songj/miniforge3/lib/python3.10/site-packages (from rasterio>=1.3.7->rioxarray) (3.1.4)
# Requirement already satisfied: pandas>=2.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from xarray>=2024.7.0->rioxarray) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/songj/miniforge3/lib/python3.10/site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/songj/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray>=2024.7.0->rioxarray) (1.16.0)

# %%
## This script is the updated version for the NAIP image downloading
## The previous version has been deprecated, since Microsoft Updated
## the data storage on Azure and transfered to the Planertory Computer
## Last modified by Xiaojiang Li, UPenn, Jan 30, 2025

## https://planetarycomputer.microsoft.com/dataset/naip#Example-Notebook

import os, os.path
from pystac_client import Client
import planetary_computer as pc
import rioxarray
import rasterio as rio
import fiona
import pyproj
import requests
from shapely.geometry import shape, Point, Polygon, mapping
from functools import partial
from shapely.ops import transform
import urllib.request
import numpy as np
import geopandas as gpd
import pyproj

# Set the environment variable PC_SDK_SUBSCRIPTION_KEY, or set it here.
# The Hub sets PC_SDK_SUBSCRIPTION_KEY automatically.
pc.settings.set_subscription_key("st=2022-06-01T22%3A55%3A32Z&se=2022-06-02T23%3A40%3A32Z&sp=rl&sv=2020-06-12&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2022-06-02T20%3A23%3A33Z&ske=2022-06-09T20%3A23%3A33Z&sks=b&skv=2020-06-12&sig=U5e1SoZGZqIcunum5BKWcmsVi2bmS1tBsr94LPI%2BLoc%3D")

# %%
# set working directory
os.chdir('/Users/songj/Documents/GitHub/ai-urban-sustainability/lab3-raster-data-manipulation')

# %%
import pystac_client
import planetary_computer

catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
# !pip install pystac_client
# !pip install planetary_computer
# !pip install rioxarray

# %%
import fiona

# Download and save the GeoJSON file
url = "https://github.com/ResidentMario/geoplot-data/raw/refs/heads/master/san-francisco.geojson"
geojson_path = "san-francisco.geojson"

response = requests.get(url)
with open(geojson_path, "wb") as file:
    file.write(response.content)

# Open the GeoJSON file
lyr = fiona.open(geojson_path)

# Extract the first feature's geometry
for feat in lyr:
    area_of_interest_city = feat["geometry"]
    break  # Stop after first feature

left, bottom, right, top = lyr.bounds
area_of_interest = {
    "type": "Polygon",
    "coordinates": [
        [
            [left, bottom],
            [right, bottom],
            [right, top],
            [left, top],
            [left, bottom],
        ]
    ],
}

print(area_of_interest)
# Out:
# {'type': 'Polygon', 'coordinates': [[[-122.514948, 37.708089], [-122.356967, 37.708089], [-122.356967, 37.811574], [-122.514948, 37.811574], [-122.514948, 37.708089]]]}

# %%
## check on GEE, https://developers.google.com/earth-engine/datasets/catalog/USDA_NAIP_DOQQ
range_time = '2016-01-01' + '/' + '2016-12-30'

search_new = catalog.search(
    collections=["naip"], intersects=area_of_interest, datetime=range_time
)

items_tiles = search_new.item_collection()

print(f"{len(items_tiles)} Items found in the 'new' range")
# Out:
# 12 Items found in the 'new' range

# %%
outfolder = 'cir-naip'
if not os.path.exists(outfolder): os.mkdir(outfolder)

## loop all the intersected tiles and download them all
for item in items_tiles:
    # href = pc.sign(item.assets["image"].href)
    href = item.assets["image"].href
    print(href)
    
    outfilename = os.path.join(outfolder, item.id + ".tif")
    urllib.request.urlretrieve(href, outfilename)
# Out:
# https://naipeuwest.blob.core.windows.net/naip/v002/ca/2016/ca_060cm_2016/37122/m_3712221_nw_10_h_20160625.tif?st=2025-02-09T18%3A51%3A53Z&se=2025-02-10T19%3A36%3A53Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-02-10T15%3A24%3A07Z&ske=2025-02-17T15%3A24%3A07Z&sks=b&skv=2024-05-04&sig=hsvQMs3oax%2BzI1gOfZGT/%2BS7lMKOqHu9N74JWOAQneE%3D
# https://naipeuwest.blob.core.windows.net/naip/v002/ca/2016/ca_060cm_2016/37122/m_3712221_ne_10_h_20160625.tif?st=2025-02-09T18%3A51%3A53Z&se=2025-02-10T19%3A36%3A53Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-02-10T15%3A24%3A07Z&ske=2025-02-17T15%3A24%3A07Z&sks=b&skv=2024-05-04&sig=hsvQMs3oax%2BzI1gOfZGT/%2BS7lMKOqHu9N74JWOAQneE%3D
# https://naipeuwest.blob.core.windows.net/naip/v002/ca/2016/ca_060cm_2016/37122/m_3712220_ne_10_h_20160625.tif?st=2025-02-09T18%3A51%3A53Z&se=2025-02-10T19%3A36%3A53Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-02-10T15%3A24%3A07Z&ske=2025-02-17T15%3A24%3A07Z&sks=b&skv=2024-05-04&sig=hsvQMs3oax%2BzI1gOfZGT/%2BS7lMKOqHu9N74JWOAQneE%3D
# https://naipeuwest.blob.core.windows.net/naip/v002/ca/2016/ca_060cm_2016/37122/m_3712213_sw_10_h_20160625.tif?st=2025-02-09T18%3A51%3A53Z&se=2025-02-10T19%3A36%3A53Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-02-10T15%3A24%3A07Z&ske=2025-02-17T15%3A24%3A07Z&sks=b&skv=2024-05-04&sig=hsvQMs3oax%2BzI1gOfZGT/%2BS7lMKOqHu9N74JWOAQneE%3D
# https://naipeuwest.blob.core.windows.net/naip/v002/ca/2016/ca_060cm_2016/37122/m_3712213_se_10_h_20160625.tif?st=2025-02-09T18%3A51%3A53Z&se=2025-02-10T19%3A36%3A53Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-02-10T15%3A24%3A07Z&ske=2025-02-17T15%3A24%3A07Z&sks=b&skv=2024-05-04&sig=hsvQMs3oax%2BzI1gOfZGT/%2BS7lMKOqHu9N74JWOAQneE%3D
# https://naipeuwest.blob.core.windows.net/naip/v002/ca/2016/ca_060cm_2016/37122/m_3712213_nw_10_h_20160625.tif?st=2025-02-09T18%3A51%3A53Z&se=2025-02-10T19%3A36%3A53Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-02-10T15%3A24%3A07Z&ske=2025-02-17T15%3A24%3A07Z&sks=b&skv=2024-05-04&sig=hsvQMs3oax%2BzI1gOfZGT/%2BS7lMKOqHu9N74JWOAQneE%3D

# %%
def naip_downloader(shpfile, outfolder, startDate, endDate):
    '''This function will use the shapefile as the limit and find the 
    tiles that overlap with the shapefile and then download those tiles
    
    Parameters:
        shpfile: the shapefile of the city limit
        outfolder: the output folder of the NAIP images
        startDate: the start date to check the NAIP inventory, year-month-day, 2017-06-01/2017-09-30
        endDate: the end date to check the available NAIP year-month-day, 2017-06-01/2017-09-30
    '''
    
    import fiona
    
    lyr = fiona.open(geojson_path)
    for feat in lyr:
        area_of_interest_city = feat['geometry']
        # print(area_of_interest)
    
    left, bottom, right, top = lyr.bounds
    area_of_interest = {
        "type": "Polygon",
        "coordinates": [
            [
                [left, bottom],
                [right, bottom],
                [right, top],
                [left, top],
                [left, bottom],
            ]
        ],
    }
    
    print(area_of_interest)
    
    range_time = startDate + '/' + endDate
    print(range_time)
    
    catalog = Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")
    
    search_tiles = catalog.search(
        collections=["naip"], intersects=area_of_interest, datetime=range_time
    )
    items_tiles = list(search_tiles.get_items())
    print(f"{len(items_tiles)} Items found in the range %s"%(range_time))
    # print(items_tiles)
    
    ## loop all the intersected tiles and download them all
    for item in items_tiles:
        # href = pc.sign(item.assets["image"].href)
        href = item.assets["image"].href
        
        outfilename = os.path.join(outfolder, item.id + ".tif")
        urllib.request.urlretrieve(href, outfilename)

        ### check if the NAIP tile intersects with the shapefile, if not remove it.
        lu_dataset = rio.open(outfilename)
        epsgcode = lu_dataset.crs.to_epsg()
        lu_bounds = lu_dataset.bounds
        lu_box = Polygon([(lu_bounds.left, lu_bounds.bottom), \
                            (lu_bounds.left, lu_bounds.top), \
                            (lu_bounds.right, lu_bounds.top), \
                            (lu_bounds.right, lu_bounds.bottom)])
        
        city_geom = shape(area_of_interest_city)
        #print('city_geom is:', city_geom)
        #print("The lubox is:", lu_box)
        
        project = pyproj.Transformer.from_proj(
            pyproj.Proj('epsg:4326'), # source coordinate system
            pyproj.Proj('epsg:%s'%(epsgcode)), 
            always_xy=True) # destination coordinate system
        city_geom_proj = transform(project.transform, city_geom)  # apply projection
        
        ## make sure the projections are consistent
        if city_geom_proj.intersects(lu_box):
            print("intersected :", outfilename)
            r = lu_dataset.read(1) ## start from 1, 2, 3, 4
            g = lu_dataset.read(2)
            b = lu_dataset.read(3)
            ir = lu_dataset.read(4)
            #rgb = np.dstack((r,g,b))
            cir = np.stack((ir,r,g,b))
            
            out_meta = lu_dataset.meta.copy()
            out_meta.update({'count': 4})
            # os.remove(outfilename)
            with rio.open(outfilename, "w", **out_meta) as dest:
                dest.write(cir)
        else:
            print("The CIR is not intersected, remove it=--------")
            os.remove(outfilename)

# %%
import os, os.path
import argparse
import geopandas as gpd

# using the reprojected geom shape to find the corresponding tile
cir_naips = 'cir-naip'
if not os.path.exists(cir_naips): os.mkdir(cir_naips)

# check on GEE, https://developers.google.com/earth-engine/datasets/catalog/USDA_NAIP_DOQQ
startDate = '2016-01-01'
endDate = '2016-12-30'
naip_downloader(geojson_path, cir_naips, startDate, endDate)
# Out:
# {'type': 'Polygon', 'coordinates': [[[-75.28030313034645, 39.867465570687145], [-74.9557457320632, 39.867465570687145], [-74.9557457320632, 40.137927528193686], [-75.28030313034645, 40.137927528193686], [-75.28030313034645, 39.867465570687145]]]}
# 2017-06-01/2017-09-30
# /Users/songj/miniforge3/lib/python3.10/site-packages/pystac_client/item_search.py:888: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# 46 Items found in the range 2017-06-01/2017-09-30
# intersected : cir-naip/pa_m_4007562_se_18_1_20170910_20171207.tif
# intersected : cir-naip/pa_m_4007562_ne_18_1_20170910_20171207.tif
# The CIR is not intersected, remove it=--------
# intersected : cir-naip/nj_m_4007564_se_18_1_20170824_20171102.tif
# intersected : cir-naip/nj_m_4007457_sw_18_1_20170824_20171102.tif
# intersected : cir-naip/nj_m_4007457_nw_18_1_20170824_20171102.tif
# The CIR is not intersected, remove it=--------
# The CIR is not intersected, remove it=--------
# The CIR is not intersected, remove it=--------
# intersected : cir-naip/nj_m_3907508_nw_18_1_20170809_20171102.tif
# intersected : cir-naip/nj_m_3907507_se_18_1_20170809_20171102.tif
# intersected : cir-naip/nj_m_3907507_ne_18_1_20170809_20171102.tif
# intersected : cir-naip/pa_m_4007556_se_18_1_20170801_20171207.tif
# The CIR is not intersected, remove it=--------
# The CIR is not intersected, remove it=--------
# intersected : cir-naip/nj_m_3907508_ne_18_1_20170731_20171102.tif
# The CIR is not intersected, remove it=--------
# The CIR is not intersected, remove it=--------
# The CIR is not intersected, remove it=--------
# intersected : cir-naip/nj_m_3907515_nw_18_1_20170730_20171102.tif
# intersected : cir-naip/nj_m_3907514_ne_18_1_20170730_20171102.tif
# intersected : cir-naip/nj_m_3907507_sw_18_1_20170730_20171102.tif
# intersected : cir-naip/pa_m_4007564_se_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007564_nw_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007564_ne_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007563_sw_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007563_se_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007563_nw_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007563_ne_18_1_20170612_20171207.tif
# The CIR is not intersected, remove it=--------
# The CIR is not intersected, remove it=--------
# The CIR is not intersected, remove it=--------
# intersected : cir-naip/pa_m_4007457_sw_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007457_nw_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007449_sw_18_1_20170612_20171207.tif
# intersected : cir-naip/pa_m_4007564_sw_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907515_nw_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907514_ne_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907508_nw_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907508_ne_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907507_sw_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907507_se_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907507_nw_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907507_ne_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907506_se_18_1_20170611_20171207.tif
# intersected : cir-naip/pa_m_3907506_ne_18_1_20170611_20171207.tif

# %% [markdown]
# #### Let just visualize one image

# %%
import rasterio as rio
from matplotlib import pyplot as plt

tiffile = 'cir-naip/pa_m_4007449_sw_18_1_20170612_20171207.tif'
dataset = rio.open(tiffile)
dataset.crs
# Out:
# CRS.from_epsg(26918)

# %%
band1 = dataset.read(1)

# %%
plt.imshow(band1)
